# %%
import pandas as pd

# %%
# https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=&ved=2ahUKEwiPpbyr2-PyAhXyVTABHYRuACgQFnoECAMQAQ&url=https%3A%2F%2Fcolaboracion.dnp.gov.co%2FCDT%2FPoltica%2520de%2520Vctimas%2FConstrucci%25C3%25B3n%2520de%2520Paz%2FIICA%2520municipal.xls&usg=AOvVaw3_7Vfrjx-nRXR2x0sx4lZ0

# %%
xls = pd.ExcelFile('Conflicto_armado.xls')

# %%
conflicto_df  = pd.read_excel(xls, 'anual')
conflicto_df_2013 = conflicto_df[conflicto_df.año == 2013]
# Out:
#       divipola Departamento       Municipio   año  \
# 0         5001    ANTIOQUIA        MEDELLÍN  2013
# 1         5002    ANTIOQUIA       ABEJORRAL  2013
# 2         5004    ANTIOQUIA        ABRIAQUÍ  2013
# 3         5021    ANTIOQUIA      ALEJANDRÍA  2013
# 4         5030    ANTIOQUIA           AMAGÁ  2013
# ...        ...          ...             ...   ...
# 1117     97889       VAUPÉS        YAVARATÉ  2013
# 1118     99001      VICHADA  PUERTO CARREÑO  2013
# 1119     99524      VICHADA    LA PRIMAVERA  2013
# 1120     99624      VICHADA   SANTA ROSALÍA  2013
# 1121     99773      VICHADA        CUMARIBO  2013
#
#       Índice de indicencia del conflicto  \
# 0                               0.008261
# 1                               0.005499
# 2                               0.000327
# 3                               0.005062
# 4                               0.016015
# ...                                  ...
# 1117                            0.000013
# ...
