# %%
#connect with drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Individual Recode
df = pd.read_stata('/content/drive/MyDrive/Nutrición/HealthDataPython/DHS/COPR72DT/COPR72FL.DTA')

# %%
df
# Out:
#                 hhid  hvidx hv000  hv001  hv002  ... sh88x  sh89  sh90  sh91  sh92
# 0           00011215      1   CO7      1   1215  ...   NaN   NaN   NaN   NaN   NaN
# 1           00011215      2   CO7      1   1215  ...   NaN   NaN   NaN   NaN   NaN
# 2           00011215      3   CO7      1   1215  ...   NaN   NaN   NaN   NaN   NaN
# 3           00011215      4   CO7      1   1215  ...   NaN   NaN   NaN   NaN   NaN
# 4           00011215      5   CO7      1   1215  ...   NaN   NaN   NaN   NaN   NaN
# ...              ...    ...   ...    ...    ...  ...   ...   ...   ...   ...   ...
# 162454      50002020      5   CO7   5000   2020  ...   NaN   NaN   NaN   NaN   NaN
# 162455      50002121      1   CO7   5000   2121  ...   NaN   NaN   NaN   NaN   NaN
# 162456      50009040      1   CO7   5000   9040  ...   NaN   NaN   NaN   NaN   NaN
# 162457      50009040      2   CO7   5000   9040  ...   NaN   NaN   NaN   NaN   NaN
# ...

# %%
df.columns
# Out:
# Index(['hhid', 'hvidx', 'hv000', 'hv001', 'hv002', 'hv003', 'hv004', 'hv005',
#        'hv006', 'hv007',
#        ...
#        'sh87o', 'sh88a', 'sh88b', 'sh88c', 'sh88d', 'sh88x', 'sh89', 'sh90',
#        'sh91', 'sh92'],
#       dtype='object', length=414)
