# %%
! pip install imagecodecs
# Out:
# ...
#      |████████████████████████████████| 29.6 MB 60 kB/s
# ...

# %%
# If you are working with a shape file stored in google drive remove the quotes (""" """)

#connect with drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/GEE\ Popayan_Month_square
# !ls
# Out:
# /content/drive/MyDrive/GEE Popayan_Month_square
# 'Image 2013_10.tif'	     'Image 2014_1.tif'   'Image 2015_3.tif'
# 'Image 2013_11.tif'	     'Image 2014_2.tif'   'Image 2015_4.tif'
# 'Image 2013_12.tif'	     'Image 2014_3.tif'   'Image 2015_5.tif'
# 'Image 2013_4.tif'	     'Image 2014_4.tif'   'Image 2015_6.tif'
# 'Image 2013_5.tif'	     'Image 2014_5.tif'   'Image 2015_7.tif'
# 'Image 2013_6.tif'	     'Image 2014_6.tif'   'Image 2015_8.tif'
# 'Image 2013_7.tif'	     'Image 2014_7.tif'   'Image 2015_9.tif'
# 'Image 2013_8_sharpend.tif'  'Image 2014_8.tif'   'Image 2016_1.tif'
# 'Image 2013_8.tif'	     'Image 2014_9.tif'   'Image 2016_2.tif'
# 'Image 2013_9_sharpend.tif'  'Image 2015_10.tif'  'Image 2016_3.tif'
# 'Image 2013_9.tif'	     'Image 2015_11.tif'  'Image 2016_4.tif'
# 'Image 2014_10.tif'	     'Image 2015_12.tif'  'Image 2016_5.tif'
# 'Image 2014_11.tif'	     'Image 2015_1.tif'    read_tif.ipynb
# 'Image 2014_12.tif'	     'Image 2015_2.tif'

# %%
from skimage import io

# %%
im = io.imread('Image 2013_8_sharpend.tif')
im.shape
# Out:
# (1664, 2757, 6)

# %%
im
# Out:
# array([[[ 56,  64,  80, 208, 108,  55],
#         [ 53,  60,  76, 208, 108,  55],
#         [ 36,  46,  63, 179,  82,  41],
#         ...,
#         [ 57,  67,  70, 255, 215, 112],
#         [ 34,  50,  59, 255, 147,  64],
#         [ 32,  48,  56, 255, 147,  64]],
#
#        [[ 58,  66,  83, 208, 108,  55],
#         [ 67,  76,  96, 208, 108,  55],
#         [ 42,  53,  73, 179,  82,  41],
#         ...,
#         [ 66,  77,  80, 255, 215, 112],
#         [ 36,  54,  63, 255, 147,  64],
#         [ 32,  47,  55, 255, 147,  64]],
#
#        [[ 59,  68,  76, 255, 142,  75],
#         [ 74,  86,  96, 255, 142,  75],
#         [ 62,  74,  86, 255, 134,  69],
#         ...,
#         [ 73,  90,  86, 255, 210, 113],
#         [ 47,  66,  73, 255, 162,  75],
#         [ 37,  53,  58, 255, 162,  75]],
#
#        ...,
#
#        [[ 28,  39,  57,  88,  47,  25],
#         [ 28,  39,  57,  93,  53,  29],
#         [ 27,  38,  55,  93,  53,  29],
#         ...,
# ...

# %%
from matplotlib import pyplot as plt
      # show [all rows, all columns, band 3 to 5] 
plt.imshow(im[:,:,3:6], interpolation='nearest')
plt.show()
